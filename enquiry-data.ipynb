# %% [markdown]
# # Cyber Square-Enquiry Data

# %% [markdown]
# # Aim:
# To explore and analyze the enquiry data from Cyber Square by performing data cleaning, analysis, and visualization to derive key business insights. Additionally, to develop a classification model that predicts whether a student will join or not, based on the enquiry data.

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Dataset loading

# %%
dt1=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\enquiry_data.xlsx")
dt1.head()
# Out:
#                Name     Location   Mobile_no                      Email  \
# 0        Shamna.E.K       Kovoor  8943469870    shamnasha9008@gmail.com
# 1          Mithun.M  Thiruvannur  9847880986   mithunmanakkal@gmail.com
# 2    Salmanul Faris         Mahe  8138899131                        NaN
# 3   Gaurika Gireesh     Vadakara  9778522602  gaurigireesh123@gmail.com
# 4  Diya Fathima.P.V       Kallai  8714888715       diafathima@gmail.com
#
#    Find_us Qualification                Branch Career_issue    Looking_for  \
# 0      NaN        Others                   NaN          NaN  IT Internship
# 1      NaN            UG                   BCA       Non IT  IT Internship
# 2      NaN            PG                   NaN          NaN         Others
# 3      NaN            UG                   NaN   Backpapers  IT Internship
# 4      NaN            UG  BSC Computer Science   Backpapers  IT Internship
#
#            Technology     Mode Time_Slot                 Date Attended_by  \
# ...

# %%
dt2=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\enquiry_data_2.xlsx")
dt2.head()
# Out:
#                    Name  Location   Mobile_no                     Email  \
# 0               Savya.K   Calicut  8590194123     savyasavz05@gmail.com
# 1          Vaishnav.C.P    Kannur  9562938792  vaishnavcp3va7@gmail.com
# 2       Muhammed Zain.M   Calicut  7593949225           zainm@gmail.com
# 3  Danil Binoy Mattayil       NaN  7306555060   binoymattayil@gmail.com
# 4             Hiba Asia  Kasargod  9746659058       hiibaaaaa@gmail.com
#
#         Find_us Qualification                Branch Career_issue  \
# 0  Social Media            UG  Computer Application          NaN
# 1  Social Media            PG                   MCA          NaN
# 2        Others            UG                   NaN          NaN
# 3           NaN           NaN                   NaN          NaN
# 4           NaN           NaN                   NaN          NaN
#
#      Looking_for Technology     Mode Time_Slot       Date Attended_by  \
# ...

# %%
dt3=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\enquiry_data_3.xlsx")
dt3.head()
# Out:
#             Name   Location   Mobile_no                       Email  Find_us  \
# 0  Jinu Prem.J.P    Calicut  9496493866        jinupremjp@gmail.com      NaN
# 1     Aneena.B.S  Balussery  6238009676        aneenabs03@gmail.com      NaN
# 2     Sharon.M.S    Kotholi  9995127178        sharonmyid@gmail.com      NaN
# 3    Jayalakshmi    Calicut  7012393118                         NaN      NaN
# 4        Shahida    Mukkonu  8547401152  shahida78shameer@yahoo.com      NaN
#
#   Qualification            Branch  Career_issue Looking_for Technology  \
# 0           NaN               NaN           NaN         NaN     Python
# 1        B.Tech  Computer Science           NaN      Others     Python
# 2           NaN               NaN           NaN         NaN     Python
# 3           NaN               NaN           NaN         NaN        NaN
# 4           NaN               NaN           NaN         NaN     Python
#
#       Mode Time_Slot       Date Attended_by  No_persons  Fee_Details  \
# ...

# %%
dt4=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\enquiry_data_4.xlsx")
dt4.head()
# Out:
#                   Name    Location     Mobile_no                      Email  \
# 0           Vishnu.C.P  Malappuram  9.072880e+09   vishnuchengott@gmail.com
# 1  Muhammed Shamil.P.K  Puthappady  8.714542e+09                        NaN
# 2    Allan Aldo Thomas      Poloor  8.089594e+09      scariaallan@gmail.com
# 3              Aruun.R    Vadakara  9.539925e+09   aruunkoodathil@gmail.com
# 4     Sanal Mohammed.P     Mathara  9.744862e+09  sanaamohammed12@gmail.com
#
#    Find_us Qualification                  Branch  Career_issue    Looking_for  \
# 0      NaN            UG                     BSC           NaN  IT Internship
# 1      NaN        Plus 2                Commerce           NaN         Others
# 2      NaN        B.Tech  Automobile Engineering           NaN  IT Internship
# 3      NaN       Diploma                     CSE           NaN      IT Course
# 4      NaN        B.Tech                     CSE           NaN            NaN
#
# ...

# %%
dt5=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\enquiry_data_5.xlsx")
dt5.head()
# Out:
#           Name   Location     Mobile_no                     Email  Find_us  \
# 0    Amal Sonu    Calicut  8.129359e+09                       NaN      NaN
# 1   Vishnu.C.P  Chelavoor  8.075982e+09  vishnufunny409@gmail.com      NaN
# 2      Adhun.P    Calicut  8.289833e+09         adhunp8@gmail.com      NaN
# 3  Shaheeb.T.K     Panoor  8.848968e+09    shabeebtk768@gmail.com      NaN
# 4    Arsha.P.K  Koyilandy  7.356345e+09   arshaashok850@gmail.com      NaN
#
#   Qualification      Branch  Career_issue    Looking_for Technology  Mode  \
# 0       Diploma  Mechanical           NaN            NaN     Python   NaN
# 1            UG         BCA           NaN  IT Internship     Python   NaN
# 2        B.Tech          IT           NaN         Others        PHP   NaN
# 3        Plus 2         NaN           NaN  IT Internship     Python   NaN
# 4        B.Tech         CSE           NaN            NaN     Python   NaN
#
# ...

# %%
dt6=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\datashadin(2).xlsx")
dt6.head()
# Out:
#             Name    Location     Mobile_no                    Email Find_us  \
# 0   badeehuzaman      mukkam  8.593897e+09    badeehuzmn1@gmail.com     NaN
# 1        harshak  kozhikkode  8.588990e+10      harshakpp@gmail.com     NaN
# 2    jalaludheen  malappuram  9.747786e+09  jalaludheenok@gmail.com     NaN
# 3  hiba parvin p  kozhikkode  9.847875e+09                      NaN     NaN
# 4  saifudheen pv  malappuram  9.072788e+09     shanurusjv@gmail.com     NaN
#
#   Qualification            Branch       Career_issue        Looking_for  \
# 0            UG          Commerce         career gap                NaN
# 1            UG          Commerce  Non it background                NaN
# 2       diploma  Computer science                NaN     work exprience
# 3            ug           physics  Non it background  short term course
# 4            ug  Computer science                NaN         internship
#
#   Technology     Mode  Time_Slot       Date  Attended_by  No_persons  \
# ...

# %%
dt7=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\boook1.xlsx")
dt7.head()
# Out:
#                 Name   Location   Mobile_no                       Email  \
# 0     Muhammed sahad    payyoli  9207821721     muhammedsahad@gmail.com
# 1          Subin P.S     faroke  7736495307    subinpakkanath@gmail.com
# 2           Shemeela   nadakavu  9061205565  shemeelamoidheen@gmail.com
# 3  kashif minhaj M.P  kozhikode  7907674091  kashifminhajkm20@gmail.com
# 4       Abid alfan U  kozhikode  9562646590       alfanabid02@gmail.com
#
#   Find_us Qualification           Branch Career_issue Looking_for  \
# 0     NaN            UG              Bca          NaN         NaN
# 1     NaN           NaN              NaN          NaN         NaN
# 2     NaN        B.tech  computerscience    careergap     Courses
# 3     NaN         other          plustwo    careergap     Courses
# 4     NaN         other          plustwo    careergap     Courses
#
#      Technology     Mode Time_Slot       Date   Attended_by  No_persons  \
# ...

# %%
dt8=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\datanidha.xlsx")
dt8.head()
# Out:
#                Name    Location     Mobile_no                         Email  \
# 0  Ajil Krishna G R  Naduvannur  9.745007e+09       ajilkrishnagr@gmail.com
# 1   Muhammed Shavil         NaN  7.326216e+09       shavilkaradev@gmail.com
# 2   Shijin Sidharth     Calicut  9.961747e+09    shijinsidharth98@gmail.com
# 3         Fiyas P K     Calicut  8.943042e+09         Fiyaspk1820@gmail.com
# 4    Shyam Krishnan   Koduvally  7.619415e+09  shyamkrishnanpv535@gmail.com
#
#    Find_us Qualification       Branch  Career_issue Looking_for Technology  \
# 0      NaN        B.tech          ECE           NaN  internship     python
# 1      NaN           BCA           CS           NaN         NaN     python
# 2      NaN           BSC  Electronics           NaN         NaN     python
# 3      NaN           BSC      Physics           NaN         NaN     python
# 4      NaN       Diploma           IT           NaN  internship     python
#
# ...

# %%
dt9=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\enquiry_data_2021.xlsx")
dt9.head()
# Out:
#                    Name     Location   Mobile_no                        Email  \
# 0           Amal Sonu.P  Karuvasseri  8129358969                          NaN
# 1          Aiswarya.K.K      Calicut  9645552675  Aiswaryasnair2016@gmail.com
# 2     Fathima Hanna.P.T    Koduvally  8086161559     fathimahannapt@gmail.com
# 3    Fathima Raniya.T.T    Narikkuni  7902335041           ranitt73@gmail.com
# 4  Mohammed Rinshad.K.V     Mooniyor  8129953102        8129953102r@gmail.com
#
#    Find_us Qualification             Branch  Career_issue  \
# 0      NaN           NaN         Mechanical           NaN
# 1      NaN        B.Tech                CSE           NaN
# 2      NaN           NaN  Computer Commerce           NaN
# 3      NaN            UG   Computer Science           NaN
# 4      NaN        Plus 2                NaN           NaN
#
#            Looking_for Technology  Mode  Time_Slot        Date Attended_by  \
# ...

# %%
dt10=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\book1.xlsx")
dt10.head()
# Out:
#                   Name       Location   Mobile_no  \
# 0               Pranav  kunnamangalam  8089746320
# 1  Ramsheena Payambrat        calicut  9846631748
# 2        Adarsh s Nair       kottayam  9745435989
# 3     Yadhu Krishna .T        calicut  6238260890
# 4   Aswathi Vishwanath     malappuram  7591978238
#
#                               Email Find_us Qualification          Branch  \
# 0           pranavrana007@gmail.com     nil        others             nil
# 1    director@skrollopenscience.com     nil       Bsc/Bca  Bioinformatics
# 2           adarshmanjoor@gmail.com     nil        B.tech      Mechanical
# 3         yadhukrishna927@gmail.com     nil        B.tech             EEE
# 4  ashwathivishwanathachu@gmail.com     nil       Diploma             nil
#
#         Career_issue            Looking_for    Technology     Mode Time_Slot  \
# 0  non IT background                    nil          mern      nil       nil
# ...

# %%
dt11=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\book2.xlsx")
dt11.head()
# Out:
#                  Name       Location   Mobile_no                      Email  \
# 0           Ayaz khan        calicut  9037369789                        nil
# 1     Muhammed nasmul       areekode  8089964138        nasmul092@gmail.com
# 2  Muhammed ashique.p    tirurangadi  8157801367  parambilashique@gmail.com
# 3           Shamees.k      koyilandy  9745076410    korothshamees@gmail.com
# 4        Shamil anfas  ramanatukkara  8848399279      shamilanfas@gmail.com
#
#         Find_us Qualification                   Branch       Career_issue  \
# 0        Google        B.tech                      cse                nil
# 1  Social media        others  business administration  non IT background
# 2     Reference          Bvoc                      nil                nil
# 3        others           Mba                      nil                nil
# 4  Social media        others                      nil  non IT background
#
# ...

# %%
dt12=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\book3.xlsx")
dt12.head()
# Out:
#                Name    Location   Mobile_no                     Email Find_us  \
# 0  Safeela nasrin.k  malappuram  8086883510                       nil     nil
# 1            Hamdan    kondotty  9048852027    hamdannajath@gmail.com     nil
# 2             Nahil     calicut  9076225623  nahilahmedlive@gmail.com     nil
# 3       Haneena .pk     calicut  8590401441        haneenpl@gmail.com     nil
# 4            Saad.k     calicut  6238937368                       nil     nil
#
#   Qualification     Branch Career_issue    Looking_for Technology     Mode  \
# 0        B.tech        ECE          nil            nil     python      nil
# 1            BA  economics          nil  IT internship     python  offline
# 2           nil        nil          nil            nil     python  offline
# 3           nil        nil          nil  IT internship       mern  offline
# 4           nil        nil          nil            nil       mern      nil
#
# ...

# %%
dt13=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\book4.xlsx")
dt13.head()
# Out:
#                Name    Location   Mobile_no                     Email Find_us  \
# 0  Safeela nasrin.k  malappuram  8086883510                       nil     nil
# 1            Hamdan    kondotty  9048852027    hamdannajath@gmail.com     nil
# 2             Nahil     calicut  9076225623  nahilahmedlive@gmail.com     nil
# 3       Haneena .pk     calicut  8590401441        haneenpl@gmail.com     nil
# 4            Saad.k     calicut  6238937368                       nil     nil
#
#   Qualification     Branch Career_issue    Looking_for Technology     Mode  \
# 0        B.tech        ECE          nil            nil     python      nil
# 1            BA  economics          nil  IT internship     python  offline
# 2           nil        nil          nil            nil     python  offline
# 3           nil        nil          nil  IT internship       mern  offline
# 4           nil        nil          nil            nil       mern      nil
#
# ...

# %%
dt14=pd.read_excel(r"C:\Users\Aysha Riya\OneDrive\Documents\book5.xlsx")
dt14.head()
# Out:
#                 Name       Location     Mobile_no                     Email  \
# 0  Muhammed najah.kp  ramanattukara  8.714428e+09   mohdnajah8353@gmail.com
# 1    muhammed rilu.p        calicut  8.389811e+09  muhammedrilu44@gmail.com
# 2         Mikhdad.mp      koyilandy  9.656441e+09                       NaN
# 3    Muhammed jaseem      malapuram  9.744109e+09       jaseemh87@gmail.com
# 4           Geethu.k          tanur  7.361874e+09      geethuktla@gmail.com
#
#    Find_us Qualification Branch  Career_issue          Looking_for Technology  \
# 0      NaN           BCA    NaN           NaN                  NaN    flutter
# 1      NaN      plus two    NaN           NaN                  NaN        NaN
# 2      NaN           BSC    NaN           NaN                  NaN     python
# 3      NaN        B.tech    cse           NaN           Internship     python
# 4      NaN           Mca    NaN           NaN  Job orineted course     python
#
# ...

# %% [markdown]
# # Concatenate the dataset

# %%
df = pd.concat([dt1, dt2, dt3, dt4, dt5, dt6, dt7, dt8, dt9, dt10, dt11, dt12, dt13, dt14], ignore_index=True)

# %%
df.head()
# Out:
#                Name     Location   Mobile_no                      Email  \
# 0        Shamna.E.K       Kovoor  8943469870    shamnasha9008@gmail.com
# 1          Mithun.M  Thiruvannur  9847880986   mithunmanakkal@gmail.com
# 2    Salmanul Faris         Mahe  8138899131                        NaN
# 3   Gaurika Gireesh     Vadakara  9778522602  gaurigireesh123@gmail.com
# 4  Diya Fathima.P.V       Kallai  8714888715       diafathima@gmail.com
#
#   Find_us Qualification                Branch Career_issue    Looking_for  \
# 0     NaN        Others                   NaN          NaN  IT Internship
# 1     NaN            UG                   BCA       Non IT  IT Internship
# 2     NaN            PG                   NaN          NaN         Others
# 3     NaN            UG                   NaN   Backpapers  IT Internship
# 4     NaN            UG  BSC Computer Science   Backpapers  IT Internship
#
#            Technology     Mode Time_Slot                 Date Attended_by  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              480 non-null    object
#  1   Location          455 non-null    object
#  2   Mobile_no         474 non-null    object
#  3   Email             428 non-null    object
#  4   Find_us           206 non-null    object
#  5   Qualification     424 non-null    object
#  6   Branch            387 non-null    object
#  7   Career_issue      225 non-null    object
#  8   Looking_for       363 non-null    object
#  9   Technology        444 non-null    object
#  10  Mode              282 non-null    object
#  11  Time_Slot         269 non-null    object
#  12  Date              458 non-null    object
#  13  Attended_by       466 non-null    object
#  14  No_persons        443 non-null    object
#  15  Fee_Details       321 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# Name                  0
# Location             25
# Mobile_no             6
# Email                52
# Find_us             274
# Qualification        56
# Branch               93
# Career_issue        255
# Looking_for         117
# Technology           36
# Mode                198
# Time_Slot           211
# Date                 22
# Attended_by          14
# No_persons           37
# Fee_Details         159
# Year_Of_pass_out     93
# Status               20
# Remarks              21
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %%
df=df.drop_duplicates()

# %%
df.describe().T
# Out:
#                   count unique                  top   freq
# Name                471    466               Pranav      2
# Location            446    205              Calicut     46
# Mobile_no         465.0  461.0         8129358969.0    2.0
# Email               419    409                  nil     11
# Find_us             197     12                  nil     61
# Qualification       415     39                   UG     93
# Branch              378     92     Computer Science     33
# Career_issue        216     13                  nil     57
# Looking_for         354     30        IT Internship     78
# Technology          435     34               Python    140
# Mode                273      9              offline    143
# Time_Slot           260     12              morning    135
# Date                449    309  2024-05-02 00:00:00      4
# Attended_by         458     26                Baiju    184
# No_persons        435.0   11.0                  1.0  286.0
# ...

# %%
#Data types
cat_cols = [
    'Location','Find_us', 'Qualification', 'Branch', 'Career_issue',
    'Looking_for', 'Technology', 'Mode', 'Time_Slot', 'Attended_by', 'Status'
]
df[cat_cols] = df[cat_cols].astype('category')
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['No_persons'] = pd.to_numeric(df['No_persons'], errors='coerce')
df['Fee_Details'] = pd.to_numeric(df['Fee_Details'], errors='coerce')
df['Year_Of_pass_out'] = pd.to_numeric(df['Year_Of_pass_out'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 471 entries, 0 to 479
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              471 non-null    object
#  1   Location          446 non-null    category
#  2   Mobile_no         465 non-null    object
#  3   Email             419 non-null    object
#  4   Find_us           197 non-null    category
#  5   Qualification     415 non-null    category
#  6   Branch            378 non-null    category
#  7   Career_issue      216 non-null    category
#  8   Looking_for       354 non-null    category
#  9   Technology        435 non-null    category
#  10  Mode              273 non-null    category
#  11  Time_Slot         260 non-null    category
#  12  Date              445 non-null    datetime64[ns]
#  13  Attended_by       458 non-null    category
#  14  No_persons        423 non-null    float64
#  15  Fee_Details       277 non-null    float64
# ...

# %% [markdown]
# # Clearing null values

# %% [markdown]
# # 1.Name

# %%
df["Name"]=df["Name"].str.lower()
df["Name"]
# Out:
# 0               shamna.e.k
# 1                 mithun.m
# 2           salmanul faris
# 3          gaurika gireesh
# 4         diya fathima.p.v
#               ...
# 475           abhilash .kr
# 476               reyal.pp
# 477    muhammed thasneem.k
# 478                praveen
# 479              ajaydev.s
# Name: Name, Length: 471, dtype: object

# %% [markdown]
# # 2.Location

# %%
df["Location"]=df["Location"].fillna("Calicut")

# %%
df["Location"]=df["Location"].str.lower()
df["Location"]=df["Location"].replace({'calicut':'kozhikode', 'bc road beypore':'beypore', 'calcu':'kozhikode', 'thamssery':'thamarassery',
                                       'artholi':'atholi', 'vadaksra':'vadakara', 'farook':'feroke', 'quilandi ':'koilandi', 'koyilandy':'koilandi',
                                       'kozhikkode':'kozhikode', 'panthirankaav':'pantheeramkavu', 'panthirankavu':'panthiramkavu', 
                                       'faroke':'feroke', 'ayikarapadi':'aikkarappadi', 'kallai':'kallayi','karaparamba':'karaparambu',
                                      'malapuram':'malappuram', 'nadakavu':'nadakkavu', 'palakad':'palakkad', ' calicut':'kozhikode', 
                                       'calicut ':'kozhikode', 'farook college':'feroke'})

# %%
df['Location'].unique()
# Out:
# array(['kovoor', 'thiruvannur', 'mahe', 'vadakara', 'kallayi', 'kannur',
#        'kozhikode', 'payyoli', 'tirur', 'kondotty', 'parappanangadi',
#        'olavanna', 'pantheerankavu', 'chevayoor', 'perambra',
#        'puthuppamba', 'kadavathur', 'malappuram', 'vellimadukkunnu',
#        'palakkad', 'kannookkara', 'kasargod', 'ponnani', 'kankot',
#        'wayanad', 'pandikkad', 'puthurmadam', 'pokkunnu', 'areekode',
#        'feroke', 'nadapuram', 'palazhi', 'atholi', 'mundayad',
#        'balussery', 'kotholi', 'mukkonu', 'chathamangalam', 'pullavoor',
#        'koduvally', 'aikkarappadi', 'maniyur', 'perumanna', 'vengaloor',
#        'maralvayal', 'kuniyil', 'chelari', 'marthottam', 'pulikkal',
#        'bitherkad', 'katholi', 'mukkam', 'ernakulam', 'vallikkunnu',
#        'puthappady', 'poloor', 'mathara', 'thenkipalam', 'kottooli',
#        'kunnathupalam', 'maankavu', 'perinthalmanna', 'beypore',
#        'kottappuram', 'moorkanad', 'chalcode', 'kadalundi', 'mayanad',
# ...

# %% [markdown]
# # 3.Mobile_no

# %%
df['Mobile_no']=df['Mobile_no'].fillna("nil")
df["Mobile_no"]=df["Mobile_no"].astype(str)
df["Mobile_no"]
# Out:
# 0        8943469870
# 1        9847880986
# 2        8138899131
# 3        9778522602
# 4        8714888715
#            ...
# 475    8129974234.0
# 476    8111905640.0
# 477             nil
# 478    9188275687.0
# 479    7510674608.0
# Name: Mobile_no, Length: 471, dtype: object

# %% [markdown]
# # 4.Email

# %%
df["Email"]=df["Email"].fillna("nil")
df["Email"]=df["Email"].str.lower()
df["Email"]
# Out:
# 0         shamnasha9008@gmail.com
# 1        mithunmanakkal@gmail.com
# 2                             nil
# 3       gaurigireesh123@gmail.com
# 4            diafathima@gmail.com
#                   ...
# 475    abhilashnambisan@gmail.com
# 476          ppreyal575@gmail.com
# 477                           nil
# 478                           nil
# 479          ajaydev002@gmail.com
# Name: Email, Length: 471, dtype: object

# %% [markdown]
# # 5.Find_us

# %%
df["Find_us"]=df["Find_us"].str.lower()
df["Find_us"]=df["Find_us"].replace({np.nan:'nil', 'other':'others', 'i':'others'})
df["Find_us"].unique()   #no need to fill with nil
# Out:
# array(['nil', 'social media', 'others', 'reference', 'google'],
#       dtype=object)

# %% [markdown]
# # 6.Qualification

# %%
df["Qualification"]=df["Qualification"].fillna("UG")
df["Qualification"]
# Out:
# 0      Others
# 1          UG
# 2          PG
# 3          UG
# 4          UG
#         ...
# 475       Mca
# 476    B.tech
# 477      Bcom
# 478       BSC
# 479        UG
# Name: Qualification, Length: 471, dtype: category
# Categories (39, object): ['B tech', 'B.Com', 'B.TECH', 'B.Tech', ..., 'pg', 'plus 2', 'plus two', 'ug']

# %%
df["Qualification"]=df["Qualification"].str.lower()
df["Qualification"]=df["Qualification"].replace({'other ':'others', 'bca':'ug', 'bsc':'ug', 'bca/bca':'ug', 'ba':'ug', 'bba':'ug', 'mca':'pg', 
                                                 'commerce':'plus 2', 'bvoc':'ug', 'mba':'pg', 'ma':'pg', 'b.tech ':'b.tech', 'bcom':'ug', 
                                                 'b.com':'ug', 'plus two':'plus 2', 'bsc/bca':'ug','other':'others','b tech':'b.tech', 'msc':'pg'})
                                                 
df["Qualification"].unique()
# Out:
# array(['others', 'ug', 'pg', 'b.tech', 'diploma', 'plus 2', 'm.tech',
#        'sslc', 'nil'], dtype=object)

# %% [markdown]
# # 7.Branch

# %%
df["Branch"]=df["Branch"].fillna("nil")
df["Branch"]
# Out:
# 0                       nil
# 1                       BCA
# 2                       nil
# 3                       nil
# 4      BSC Computer Science
#                ...
# 475              applicaton
# 476                     cse
# 477                     nil
# 478                     nil
# 479                     nil
# Name: Branch, Length: 471, dtype: category
# Categories (92, object): [2, ' Plus Two', 'AEI', 'AI', ..., 'science', 'video editing', 'zology', 'zoology']

# %%
df["Branch"]=df["Branch"].str.lower()
df["Branch"]=df["Branch"].replace({'zology':'zoology', 'bsc computer science':'computer science', 'computerscience':'computer science', 
                                   'e&c':'electronics and communication', 'civil engineeering':'ce', 'civil':'ce',
                                   'i t':'it', 'cs':'computer science', 'aei':'ai', 'cs ':'computer science', 'mechanical':'me',
                                  'honars n mathematics':'mathematics', np.nan:'nil', 'plustwo':'science', 'civil engineering':'ce',
                                  'mechanical engineering':'me'})
df["Branch"].unique()
# Out:
# array(['nil', 'bca', 'computer science', 'b.com',
#        'computer science and engineering', 'bba', 'finance',
#        'computer science ', 'computer hardware and networking',
#        'computer application', 'mca', 'me', 'commerce', 'statistics',
#        'electronics', 'plus 2', 'm.com', ' plus two', 'it', 'other',
#        'electrical', 'bsc', 'automobile engineering', 'cse', 'ece',
#        'politics', 'engineering management', 'digital engineering',
#        'chemistry', 'computer engineering', 'eee', 'ce',
#        'electronics and communication', 'ca', 'thermal engineering',
#        'physics', 'psycology', 'zoology', 'science', 'english', 'ct',
#        'video editing', 'bcom', 'bvoc', 'ec', 'co-operation',
#        'computer commerce', 'computer hardware', 'automobile', 'ai',
#        'bioinformatics', 'business administration', 'ba sociology',
#        'graphic web', 'mathematics', 'economics', 'humanities',
#        'english ', 'applicaton'], dtype=object)

# %% [markdown]
# # 8.Career_issue

# %%
df["Career_issue"]=df["Career_issue"].fillna("nil")
df["Career_issue"]
# Out:
# 0             nil
# 1          Non IT
# 2             nil
# 3      Backpapers
# 4      Backpapers
#           ...
# 475           nil
# 476           nil
# 477           nil
# 478           nil
# 479           nil
# Name: Career_issue, Length: 471, dtype: category
# Categories (13, object): ['Backpaper', 'Backpapers', 'Career Gap', 'Career gap', ..., 'nil', 'nil ', 'non IT background', 'non-it']

# %%
df["Career_issue"]=df["Career_issue"].str.lower()
df["Career_issue"]=df["Career_issue"].replace({'backpaper':'backpapers', 'careergap':'career gap', 'non-it':'non it background', 
                                               'nil ':'nil', 'non it':'not it background', 'not it background':'non it background', 
                                              'non it background':'non it background'})
df["Career_issue"].unique()
# Out:
# array(['nil', 'not it background', 'backpapers', 'career gap',
#        'non it background'], dtype=object)

# %% [markdown]
# # 9.Looking_for

# %%
df["Looking_for"]=df["Looking_for"].fillna("IT Internship")
df["Looking_for"]
# Out:
# 0      IT Internship
# 1      IT Internship
# 2             Others
# 3      IT Internship
# 4      IT Internship
#            ...
# 475    IT Internship
# 476    IT Internship
# 477    IT Internship
# 478    IT Internship
# 479    IT Internship
# Name: Looking_for, Length: 471, dtype: category
# Categories (30, object): ['Courses', 'I t internship', 'IT  Work Experience', 'IT Course', ..., 'others', 'others ', 'short term course', 'work exprience']

# %%
df["Looking_for"]=df["Looking_for"].str.lower()
df["Looking_for"]=df["Looking_for"].replace({'it course':'it courses', 'industrial experience':'others', 'it  work experience':'it work experience',
                                             'work exprience':'it work experience', 'internship':'it internship', 'iv':'others', 'courses':'it courses',
                                             'intership':'it internship', 'work experience':'it work experience', 'job oriented course':'others', 
                                             'i t internship':'it internship', 'it internship ':'it internship', 'others ':'others', 
                                            'it crash course ':'it courses', 'job orineted course':'others','short term course':'others'})
df["Looking_for"].unique()
# Out:
# array(['it internship', 'others', 'it work experience', 'it courses',
#        'nil'], dtype=object)

# %% [markdown]
# # 10.Technology

# %%
df["Technology"]=df["Technology"].fillna("Python")
df["Technology"]
# Out:
# 0                  Python
# 1                 Flutter
# 2      Business Analytics
# 3                  Python
# 4                 Flutter
#               ...
# 475                python
# 476                python
# 477                python
# 478                python
# 479                python
# Name: Technology, Length: 471, dtype: category
# Categories (34, object): ['AI', 'Angular', 'Artificial Intelligence', 'Business Analytics', ..., 'python', 'python ', 'react', 'web designing']

# %%
df["Technology"]=df["Technology"].str.lower()
df["Technology"]=df["Technology"].replace({'java':'others', 'data analysis':'others', 'java script':'others', 'other':'others', 'web designing':'others',
                                           'javascript':'others', 'artificial intelligence':'ai', 'flutter ':'flutter', 'data science ':'data science',
                                           'python ':'python', 'php ':'php', 'devops':'others'})
df["Technology"].unique()
# Out:
# array(['python', 'flutter', 'business analytics', 'others', 'mern',
#        'react', 'data science', 'ai', 'php', 'angular', 'nil'],
#       dtype=object)

# %% [markdown]
# # 11.Mode

# %%
df["Mode"]=df["Mode"].fillna("Offline")
df["Mode"]
# Out:
# 0      Offline
# 1      Offline
# 2      Offline
# 3      Offline
# 4      Offline
#         ...
# 475    Offline
# 476    Offline
# 477    Offline
# 478    Offline
# 479    Offline
# Name: Mode, Length: 471, dtype: category
# Categories (9, object): ['0f', 'Hybrid', 'Offline', 'Online', ..., 'nil', 'offline', 'offline ', 'online']

# %%
df["Mode"]=df["Mode"].str.lower()
df["Mode"]=df["Mode"].replace({'0f':'offline', 'offline ':'offline'})
df["Mode"].unique()
# Out:
# array(['offline', 'hybrid', 'online', 'nil'], dtype=object)

# %% [markdown]
# # 12.Time_Slot

# %%
df["Time_Slot"]=df["Time_Slot"].fillna("morning")
df["Time_Slot"]
# Out:
# 0      morning
# 1      morning
# 2      Morning
# 3      Morning
# 4      Morning
#         ...
# 475    morning
# 476    morning
# 477    morning
# 478    morning
# 479    morning
# Name: Time_Slot, Length: 471, dtype: category
# Categories (12, object): ['Afternoon', 'Morning', 'Weekend', 'afternoon', ..., 'nil', 'nil ', 'nil;', 'weekend']

# %%
df["Time_Slot"]=df["Time_Slot"].str.lower()
df["Time_Slot"]=df["Time_Slot"].replace({'evening':'afternoon', 'nil;':'nil', 'afternoon ':'afternoon', 'morning ':'morning', 'nil ':'nil'})
df["Time_Slot"].unique()
# Out:
# array(['morning', 'afternoon', 'weekend', 'nil'], dtype=object)

# %% [markdown]
# # 13.Date

# %%
df["Date"]=df["Date"].fillna(method='ffill')
df["Date"]
# Out:
# 0     2024-05-14
# 1     2024-03-23
# 2     2024-05-25
# 3     2024-05-27
# 4     2024-05-27
#          ...
# 475   2022-03-11
# 476   2022-03-31
# 477   2022-04-01
# 478   2022-04-01
# 479   2022-08-02
# Name: Date, Length: 471, dtype: datetime64[ns]

# %% [markdown]
# # 14.Attended_by

# %%
df["Attended_by"]=df["Attended_by"].fillna("Baiju")
df["Attended_by"]
# Out:
# 0           Baiju
# 1      Sivaprasad
# 2           Baiju
# 3           Baiju
# 4           Baiju
#           ...
# 475       anupama
# 476       anupama
# 477         Baiju
# 478         Baiju
# 479         Baiju
# Name: Attended_by, Length: 471, dtype: category
# Categories (26, object): ['Anupama', 'Athulya', 'Baiju', 'Deepak', ..., 'rifana', 'shiva prasad', 'shivaprasad', 'sivaprasad']

# %%
df["Attended_by"]=df["Attended_by"].str.lower()
df["Attended_by"]=df["Attended_by"].replace({'rifana':'rifna', 'baiju ':'baiju', 'anupama ':'anupama', 'shiva prasad':'sivaprasad', 
                                             'shivaprasad':'sivaprasad', 'legha':'lekha', 'lekha r':'lekha', 'legha ':'legha'})
df["Attended_by"].unique()
# Out:
# array(['baiju', 'sivaprasad', 'rifna', 'athulya', 'remin', 'shiju',
#        'anupama', 'lekha', 'faisal', 'monish', 'legha', 'shafeeque',
#        'deepak', 'praveena', 'nil', 'anusree'], dtype=object)

# %% [markdown]
# # 15.No_persons

# %%
df["No_persons"]=df["No_persons"].fillna("1")
df["No_persons"]
# Out:
# 0      1.0
# 1      1.0
# 2      2.0
# 3      2.0
# 4      3.0
#       ...
# 475    1.0
# 476    1.0
# 477    5.0
# 478    3.0
# 479    3.0
# Name: No_persons, Length: 471, dtype: object

# %%
df["No_persons"]=df["No_persons"].astype(int)
df["No_persons"].unique()
# Out:
# array([ 1,  2,  3,  4,  5, 16,  6,  7, 12, 15])

# %% [markdown]
# # 16.Fee_Details

# %%
df["Fee_Details"]=df["Fee_Details"].fillna(29500)
df["Fee_Details"]
# Out:
# 0      35400.0
# 1      59000.0
# 2      57000.0
# 3      55000.0
# 4      29500.0
#         ...
# 475    29500.0
# 476    29500.0
# 477    29500.0
# 478    29500.0
# 479    29500.0
# Name: Fee_Details, Length: 471, dtype: float64

# %% [markdown]
# # 17.Year_of_pass_out

# %%
df["Year_Of_pass_out"]=df["Year_Of_pass_out"].fillna("2025")
df["Year_Of_pass_out"]
# Out:
# 0        2025
# 1      2024.0
# 2      2024.0
# 3      2024.0
# 4      2025.0
#         ...
# 475    2018.0
# 476    2016.0
# 477      2025
# 478      2025
# 479      2025
# Name: Year_Of_pass_out, Length: 471, dtype: object

# %% [markdown]
# # 18.Status

# %%
df["Status"]=df["Status"].str.lower()
df["Status"]=df["Status"].replace({'cancelled':'no', 'joined':'yes', 'yes ':'yes', 'yes  ':'yes', 'no ':'no', 'not joined':'no', np.nan:'nil'})
df["Status"].unique()
# Out:
# array(['yes', 'no', 'nil'], dtype=object)

# %%
df["Status"].value_counts()
# Out:
# Status
# yes    237
# no     215
# nil     19
# Name: count, dtype: int64

# %%
droped_status=df["Status"].dropna()
df=df.dropna(subset=["Status"])

# %% [markdown]
# # 19.Remarks

# %%
df["Remarks"]=df["Remarks"].str.lower()
df["Remarks"]=df["Remarks"].str.strip()
df["Remarks"]=df["Remarks"].replace({'not interested':'not intrested', 'forwarded to arabic':'went abroad', 'went to abudhabi':'went abroad',
                            'pg':'going for higher studies', 'not picking':'call not picking', 'low fee':'high fee', 'canceled':'cancelled',
                            'enquiry for friend':'enquired for friend', np.nan:'nil', 'closed lost ':'closed lost', 'suspected softronix':'suspected',
                            'jined':'joined', 'np':'call not picking', 'joined another institution':'joined other institution', 
                            'found other':'joined other institution', 'suspected ':'suspected', 'no':'not intrested', 'disonnected':'suspected',
                            'joined at kondotty sql':'joined other institution'})
                                     
df["Remarks"].unique()
# Out:
# array(['joined', 'closed lost', 'nil', 'rush shedule', 'suspected',
#        'not looking it', 'having backpapers', 'looking for ui/ux',
#        'no certificate needed', 'joined other institution',
#        'call not picking', 'faculty shortage', 'no update',
#        'digital marketing', 'went abroad', 'waiting for interview result',
#        'going for higher studies', 'sample enquiry',
#        'enquired for friend', 'cancelled', 'not intrested',
#        'not responding', 'number busy', 'no contacts', 'not joined',
#        'fake', 'high fee', 'will update', 'not applicable'], dtype=object)

# %%
droped_remarks=df["Remarks"].dropna()
df=df.dropna(subset=["Remarks"])

# %%
df.isna().sum()
# Out:
# Name                0
# Location            0
# Mobile_no           0
# Email               0
# Find_us             0
# Qualification       0
# Branch              0
# Career_issue        0
# Looking_for         0
# Technology          0
# Mode                0
# Time_Slot           0
# Date                0
# Attended_by         0
# No_persons          0
# Fee_Details         0
# Year_Of_pass_out    0
# Status              0
# Remarks             0
# dtype: int64

# %%
def details(fee):
    if fee <= 15000: 
        return "One month"
    elif 15000<fee<=36000:
        return "three month"
    else:
        return "Six month"
df["Course_duration"]=df["Fee_Details"].apply(details)

# %%
df['Year_Of_Enq']=df['Date'].dt.year
df['Month_Of_Enq']=df['Date'].dt.month

# %%
df.head()
# Out:
#                Name     Location   Mobile_no                      Email  \
# 0        shamna.e.k       kovoor  8943469870    shamnasha9008@gmail.com
# 1          mithun.m  thiruvannur  9847880986   mithunmanakkal@gmail.com
# 2    salmanul faris         mahe  8138899131                        nil
# 3   gaurika gireesh     vadakara  9778522602  gaurigireesh123@gmail.com
# 4  diya fathima.p.v      kallayi  8714888715       diafathima@gmail.com
#
#   Find_us Qualification            Branch       Career_issue    Looking_for  \
# 0     nil        others               nil                nil  it internship
# 1     nil            ug               bca  not it background  it internship
# 2     nil            pg               nil                nil         others
# 3     nil            ug               nil         backpapers  it internship
# 4     nil            ug  computer science         backpapers  it internship
#
#            Technology  ...       Date Attended_by No_persons Fee_Details  \
# ...

# %% [markdown]
# # Visualisations

# %% [markdown]
# # Trending technology

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Technology', data=df, order=df['Technology'].value_counts().index, palette='Set2')
plt.title('Trending Technology')
plt.xlabel('Technology')
plt.ylabel('Number of Participants')
plt.show()

# %% [markdown]
# - Students are most interested in Python among other technolgies.
# - Flutter, MERN, and Data Science also show good participation.
# - AI, Angular, React, and Business Analytics have very few counts, indicating lower interest.

# %% [markdown]
# # Technology trend by year

# %%
dft = df.groupby(['Year_Of_Enq', 'Technology']).size().unstack(fill_value=0)

# %%
for tech in dft.columns:
    plt.figure(figsize=(6, 4))
    plt.plot(dft.index, dft[tech], marker='o', linestyle='-', label=tech)
    plt.title(f'{tech} Trends Over Time')
    plt.xlabel('Year')
    plt.ylabel('Count')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# - Python dominates overall — peaking in 2022 (90) and staying strong through 2025.
#
# - Data Science surged from 0 in 2022 to 15 in 2025, showing fast-growing interest.
#
# - MERN Stack steadily rose, hitting its highest count (18) in 2025.
#
# - Flutter saw a sharp rise in 2022 (22) but slightly declined afterward.
#
# - Angular peaked in 2022 (6) and then dropped to zero — indicating a loss of popularity.
#
# - PHP declined after 2021, suggesting reduced new enrollments.
#
# - Web Designing fell to almost zero by 2024–2025, signaling waning demand.
#
# - AI and DevOps appeared only from 2024 onward — both emerging technologies.
#
# - 2024 was the overall peak year for most technologies before a mild drop in 2025.
#
# - Overall trend: shift from traditional stacks (PHP, Angular, Web Design) to modern, data-driven and full-stack fields (Python, Data Science, MERN, DevOps).

# %% [markdown]
# # Issues faced by enquiries

# %%
df[df["Status"]=='yes'].groupby(df['Career_issue']).size()
# Out:
# Career_issue
# backpapers            16
# career gap            35
# nil                  151
# non it background     31
# not it background      4
# dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.pie(df['Career_issue'].value_counts(),autopct='%1.1f%%',labels=df['Career_issue'].value_counts().index)
plt.title("Number of enquiries by Career issue")
plt.legend()

# %% [markdown]
# - 15.7.8% of Enquiries are from non-it bg students

# %% [markdown]
# # Mode preference per technology

# %%
cross = pd.crosstab(df['Technology'], df['Mode'])
cross.plot(kind='bar', stacked=True, figsize=(10,5), colormap='Set2')
plt.title("Mode Preference by Technology (Stacked Bar)")
plt.xlabel("Technology")
plt.ylabel("Count")
plt.legend(title="Mode")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Offline(yellow) mode is most preffered across all technologies.
# - Python has the highest overall interest, with a very high offline count.
# - Flutter, MERN, and Data Science also show good participation, mostly in offline mode, followed by small portions in online and hybrid.
# - The online(gray) and hybrid(green) modes are minimal, showing that offline learning dominates strongly.
# - AI, Angular, React, and Business Analytics have very few counts, indicating lower interest, with all count.

# %% [markdown]
# # Location over joining status

# %%
dfl=df[df['Status']=='yes'].groupby(df['Location']).size().sort_values(ascending=False).head()
dfl
# Out:
# Location
# kozhikode     78
# malappuram    19
# kannur         6
# mukkam         6
# vadakara       5
# dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.barplot(df[df['Status']=='yes'].groupby(df['Location']).size().sort_values(ascending=False).head(),color='green')
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# - Kozhikkode has highest enrolled count with total number of 80
# - By looking at graph,company marketing only focusing on malabar region of kerala

# %% [markdown]
# # Enquiries based on Location

# %%
attended_counts = df['Location'].head(10).value_counts()
plt.figure(figsize=(7,7))
plt.pie(attended_counts, labels=attended_counts.index, autopct='%1.1f%%',startangle=90, colors=sns.color_palette("pastel"))

plt.title("Enquiries based on Location")
plt.show()

# %% [markdown]
# - Kozhikode has the largest slice(20%), represent where most enquiries came from.
# - All other locations contribute equally(10%), showing a balanced distribution of enquiries.

# %% [markdown]
# # Joining status distribution (overall)

# %%
plt.figure(figsize=(6, 4))
df['Status'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140)
plt.title('Joining Status Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# Most people have a definite joining status
# >Yes - 50.3%:
# - Slightly more than half of the individuals enquired.
# >No – 45.6%:
# - Nearly half of the individuals did not join.
# >Nil – 4.0%:
# - A small fraction has no recorded status.

# %% [markdown]
# # Fee Distribution by Number of Persons

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='No_persons', y='Fee_Details')
plt.title('Fee Distribution by Number of Persons')
plt.xlabel('No. of Persons')
plt.ylabel('Fee Paid')
plt.show()

# %% [markdown]
# >1–3 persons:
# - show high variability in fees.
# - Some individuals paid as low as near ₹0–₹10,000, while others paid up to ₹60,000.
# >4–7 persons:
# - Narrow boxes, meaning more consistent fees.
# - Median fee values are generally around ₹30,000–₹45,000.
# - A few outliers exist around ₹60,000.
# >12, 15, 16 persons:
# - Very few data points
# - Their boxes are essentially flat lines, that means no variations.
# - Fees are around 30,000 or below, suggesting discount package as more no. of persons.

# %% [markdown]
# # Status per attendee

# %%
ab=df.groupby(['Attended_by', 'Status']).size().reset_index(name='Count')
plt.figure(figsize=(13, 5))
sns.barplot(data=ab, x='Attended_by', y='Count', hue='Status')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Baiju is the top performer with the most enquiry and high joined(yes) rate.
# - Anupama also shows strong results.
# - Sivaprasad is fairly balanced but with some nil responses.
# - Others have low counts or mostly negative results.

# %% [markdown]
# # Trend of joining by year

# %%
df['Year'] = df['Date'].dt.year
df_filtered = df[(df['Year'] >= 2020) & (df['Year'] <= 2025)]
join_counts = df_filtered[df_filtered['Status'] == 'yes'].groupby('Year').size().reset_index(name='Count')
plt.figure(figsize=(10,5))
sns.lineplot(data=join_counts, x='Year', y='Count', marker='o')
plt.title('Trend of Joinings from 2020 to 2025')
plt.xlabel('Year')
plt.ylabel('Number of Joinings')
plt.xticks(join_counts['Year'])
plt.grid(True)
plt.show()

# %% [markdown]
# - Joining started in 2021 and peaked in significantly in 2022.
# - And then Steep decline in 2023.
# - Joinings increased again in 2024.
# - A small decrease happened again in 2025.
# - Overall, Year 2022 has maximum joinings.

# %% [markdown]
# # Monthly joining trend in each year to find patterns

# %%
df2=df[df['Status']=='yes'].groupby(['Year_Of_Enq', 'Month_Of_Enq']).size()

# %%
df2=pd.DataFrame(df2)
df2=df2.rename(columns={0:'Count'})

# %%
df2
# Out:
#                           Count
# Year_Of_Enq Month_Of_Enq
# 2021        1                 2
#             2                 2
#             3                15
#             4                 4
#             5                 1
#             6                 1
#             8                 2
#             9                 5
#             10                2
#             11                8
#             12               10
# 2022        1                 5
#             2                 2
#             3                 1
#             4                 5
#             5                 9
#             6                13
#             7                 6
#             8                 6
#             9                15
#             10                4
#             11               12
# 2023        8                 5
#             9                 5
#             10                3
#             11                3
#             12                1
# ...

# %%
df2.to_excel("year&month.xlsx")

# %%
df3=pd.read_excel("year&month.xlsx")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year_Of_Enq   5 non-null      float64
#  1   Month_Of_Enq  41 non-null     int64
#  2   Count         41 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 1.1 KB

# %%
df3
# Out:
#     Year_Of_Enq  Month_Of_Enq  Count
# 0        2021.0             1      2
# 1           NaN             2      2
# 2           NaN             3     15
# 3           NaN             4      4
# 4           NaN             5      1
# 5           NaN             6      1
# 6           NaN             8      2
# 7           NaN             9      5
# 8           NaN            10      2
# 9           NaN            11      8
# 10          NaN            12     10
# 11       2022.0             1      5
# 12          NaN             2      2
# 13          NaN             3      1
# 14          NaN             4      5
# 15          NaN             5      9
# 16          NaN             6     13
# 17          NaN             7      6
# 18          NaN             8      6
# 19          NaN             9     15
# 20          NaN            10      4
# 21          NaN            11     12
# 22       2023.0             8      5
# 23          NaN             9      5
# ...

# %%
df2021=df3.iloc[:11]
df2021['Year_Of_Enq']=df2021['Year_Of_Enq'].fillna(2021)
df2021
# Out:
#     Year_Of_Enq  Month_Of_Enq  Count
# 0        2021.0             1      2
# 1        2021.0             2      2
# 2        2021.0             3     15
# 3        2021.0             4      4
# 4        2021.0             5      1
# 5        2021.0             6      1
# 6        2021.0             8      2
# 7        2021.0             9      5
# 8        2021.0            10      2
# 9        2021.0            11      8
# 10       2021.0            12     10

# %% [markdown]
# - 2021 Monthly enrolls(Joined Count),missing data of july month maybe no joins in that month

# %%
plt.figure(figsize=(15,5))
plt.plot(df2021['Month_Of_Enq'],df2021['Count'],color='green',linewidth=2.5,marker='o')
plt.fill_between(df2021['Month_Of_Enq'],df2021['Count'],color='lightgreen')
plt.xticks(ticks=df2021['Month_Of_Enq'],labels=['jan','feb','mar','apr','may','jun','aug','sep','oct','nov','dec'])
plt.title("Year 2021 monthly Enrolled Count")
plt.xlabel("Month")
plt.ylabel("Number Of Joined")
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# - peak enrollment happened in march month of 2021
# - data's of july month is missing maybe no enrolls or missing
# - After april month enroll trend downwards,but regains after august month
# - March is when Academic year of kerela unniversity ends maybe thats because number of enrolls increased in march

# %%
df2022=df3.iloc[11:22]
df2022
# Out:
#     Year_Of_Enq  Month_Of_Enq  Count
# 11       2022.0             1      5
# 12          NaN             2      2
# 13          NaN             3      1
# 14          NaN             4      5
# 15          NaN             5      9
# 16          NaN             6     13
# 17          NaN             7      6
# 18          NaN             8      6
# 19          NaN             9     15
# 20          NaN            10      4
# 21          NaN            11     12

# %% [markdown]
# > 2022 Monthly enrolls(Joined Count),missing data of december month maybe no joins in that month

# %%
plt.figure(figsize=(15,5))
plt.plot(df2022['Month_Of_Enq'],df2022['Count'],color='green',linewidth='2.5',marker='o')
plt.fill_between(df2022['Month_Of_Enq'],df2022['Count'],color='lightgreen')
plt.title("2022 Monthly Analysis")
plt.xticks(ticks=df2022['Month_Of_Enq'],labels=['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov',])
plt.xlabel("Month")
plt.ylabel("Count")
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# - peak enrollment happend in september month in 2022
# - enrollment trend upwards after march month
# - College closures drive enrollment increases

# %%
df2023=df3.iloc[22:27]
df2023
# Out:
#     Year_Of_Enq  Month_Of_Enq  Count
# 22       2023.0             8      5
# 23          NaN             9      5
# 24          NaN            10      3
# 25          NaN            11      3
# 26          NaN            12      1

# %% [markdown]
# > 2023 Monthly enrolls(Joined Count),missing data of december month maybe no joins in that month

# %%
plt.figure(figsize=(15,5))
plt.plot(df2023['Month_Of_Enq'],df2023['Count'],color='red',linewidth='2.5',marker='o')
plt.fill_between(df2023['Month_Of_Enq'],df2023['Count'],color='lightcoral')
plt.title("2023 Monthly Analysis")
plt.xticks(ticks=df2023['Month_Of_Enq'],labels=['aug','sep','oct','nov','dec'])
plt.xlabel("Month")
plt.ylabel("Count")
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# - Details of 4 month only avaialble in 2023
# - only 6th enrollments happened in aug month and that is the peakest enrollment happened in 2023
# - Overall 2023 was not a good year for company

# %%
df2024=df3.iloc[27:35]
df2024
# Out:
#     Year_Of_Enq  Month_Of_Enq  Count
# 27       2024.0             1      2
# 28          NaN             2      9
# 29          NaN             3      5
# 30          NaN             4      2
# 31          NaN             5      9
# 32          NaN             6     12
# 33          NaN             7     10
# 34          NaN             8      1

# %% [markdown]
# > 2024 Monthly enrolls(Joined Count),missing data of sep,oct,nov,dec month maybe no joins in that month

# %%
plt.figure(figsize=(15,5))
plt.plot(df2024['Month_Of_Enq'],df2024['Count'],color='green',linewidth='2.5',marker='o')
plt.fill_between(df2024['Month_Of_Enq'],df2024['Count'],color='lightgreen')
plt.title("2024 Monthly Analysis")
plt.xticks(ticks=df2024['Month_Of_Enq'],labels=['jan','feb','mar','apr','may','jun','jul','aug'])
plt.xlabel("Month")
plt.ylabel("Count")
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# - peak enrollment happend in may,jun,jul
# - enrollment trend upwards after april month and downward after july maintaning a pattern
# - overall good year for company
# - College closures drive enrollment increases.

# %%
df2025=df3.iloc[35:]
df2025 = df2025.sort_values(by=['Year_Of_Enq', 'Month_Of_Enq'], na_position='last').reset_index(drop=True)
df2025
# Out:
#    Year_Of_Enq  Month_Of_Enq  Count
# 0       2025.0             2      1
# 1          NaN             3      4
# 2          NaN             4      8
# 3          NaN             5     19
# 4          NaN             6      7
# 5          NaN             9      1

# %% [markdown]
# > Monthly enrolls(Joined Count),missing data of jul,aug,sep,oct,nov,dec month maybe no joins in that month

# %%
plt.figure(figsize=(15,5))
plt.plot(df2025['Month_Of_Enq'],df2025['Count'],color='green',linewidth='2.5',marker='o')
plt.fill_between(df2025['Month_Of_Enq'],df2025['Count'],color='lightgreen')
plt.title("2025 Monthly Analysis")
plt.xticks(ticks=df2025['Month_Of_Enq'],labels=['jan','feb','mar','apr','may','jun'])
plt.xlabel("Month")
plt.ylabel("Count")
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# # The Type Students Looking for

# %%
plt.figure(figsize=(6, 4))
df['Looking_for'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140)
plt.title('The Type Students Looking for')
plt.ylabel('')
plt.show()

# %% [markdown]
# - IT Internship is the most students looking for.
# - IT Work Experience is the least students looking for.

# %% [markdown]
# # Course duration analysis

# %%
sns.barplot(df[df['Status']=='yes'].groupby(df['Course_duration']).size())
# Out:
# <Axes: xlabel='Course_duration'>

# %%
df[df['Status']=='yes'].groupby(df['Course_duration']).size()
# Out:
# Course_duration
# One month        7
# Six month       82
# three month    148
# dtype: int64

# %% [markdown]
# > Most of enrolls taking 6 month duration

# %% [markdown]
# # Reasons for Cancelling

# %%
dfr=df[df['Status']=='no'].groupby(df['Remarks']).size()
dfr
# Out:
# Remarks
# call not picking                75
# cancelled                       33
# closed lost                     24
# digital marketing                1
# enquired for friend              1
# faculty shortage                 1
# fake                             2
# going for higher studies         4
# having backpapers                1
# high fee                         3
# joined other institution         5
# looking for ui/ux                1
# nil                              1
# no certificate needed            1
# no contacts                      1
# no update                       26
# not applicable                   1
# not intrested                    8
# not joined                       2
# not looking it                   1
# not responding                   1
# number busy                      2
# rush shedule                     1
# sample enquiry                   1
# suspected                       14
# waiting for interview result     1
# ...

# %% [markdown]
# > joined reasons, 79 enquiries lost becuase of call not picking

# %%
plt.figure(figsize=(15,6))
sns.barplot(df[df['Status']=='no'].groupby(df['Remarks']).size(),palette=['indianred'])
plt.xticks(rotation=90)
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Best Platform For marketing

# %%
df[df['Status']=='yes'].groupby(df['Find_us']).size()
# Out:
# Find_us
# google            2
# nil             180
# others            7
# reference        26
# social media     22
# dtype: int64

# %% [markdown]
# > count of enrolled students and where they foud it

# %%
plt.figure(figsize=(15,6))
sns.barplot(df[df['Status']=='yes'].groupby(df['Find_us']).size())
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# > Most of joined enquiries are  through refferels

# %% [markdown]
# # Year Base Revenue

# %%
df.groupby('Status')['Fee_Details'].sum().iloc[1]
# Out:
# np.float64(7600600.0)

# %%
dfa=df.groupby(['Status','Year_Of_Enq'])['Fee_Details'].sum()
dfa=pd.DataFrame(dfa)
dfa.drop(['no'],axis=0,)
# Out:
#                     Fee_Details
# Status Year_Of_Enq
# nil    2021             29500.0
#        2022             59000.0
#        2023             29500.0
#        2024            257500.0
#        2025            338900.0
# yes    2021           1644600.0
#        2022           2469800.0
#        2023            842000.0
#        2024           2261300.0
#        2025           1653000.0

# %% [markdown]
# > Total revenue by year,2022 is the best year for company

# %% [markdown]
# # Quaificaton and number of student joined

# %%
df[df['Status']=='yes'].groupby(df['Qualification']).size()
# Out:
# Qualification
# b.tech      57
# diploma     14
# m.tech       1
# nil          6
# others      26
# pg          13
# plus 2       9
# ug         111
# dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.barplot(df[df['Status']=='yes'].groupby(df['Qualification']).size(),palette=['orange'])
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# > Most of Students are coming after ug,so can focus on upskilling

# %% [markdown]
# # Model building

# %% [markdown]
# > Builiding ML model For predictinng weather a enquiry wil enroll or not

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Mobile_no', 'Email', 'Find_us', 'Qualification',
#        'Branch', 'Career_issue', 'Looking_for', 'Technology', 'Mode',
#        'Time_Slot', 'Date', 'Attended_by', 'No_persons', 'Fee_Details',
#        'Year_Of_pass_out', 'Status', 'Remarks', 'Course_duration',
#        'Year_Of_Enq', 'Month_Of_Enq', 'Year'],
#       dtype='object')

# %% [markdown]
# ### Selecting Features:-
# * Find_us:- Which platform affects most of enrolls
# * Qualification_Modified:- which educated peapole are enrolling more
# * Career_Issue :- People With Which problem Enrolling more
# * Looking_for:- which service is affecting people to join
# * Technology :-Which Technology is attractng
# * Mode:- Mode of class
# * Time_Slot:-of class
# * Attended_by:-convinciing is a good feature for joining
# * No_person :- Joined with friennds?
# * Year_of_pass_out:-There will be a relation b/w passout and enquiry and join
# * Year_of_Enq:-Enq yr will affect the joining
# * Duration(month):-which month of course is making em
# * Remark_cat:categorised remark

# %% [markdown]
# # Preprocessing

# %% [markdown]
# > Encoding

# %%
le=LabelEncoder()
df['Find_us']=le.fit_transform(df['Find_us'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# google:0
# nil:1
# others:2
# reference:3
# social media:4

# %%
df['Qualification']=le.fit_transform(df['Qualification'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# b.tech:0
# diploma:1
# m.tech:2
# nil:3
# others:4
# pg:5
# plus 2:6
# sslc:7
# ug:8

# %%
df['Career_issue']=le.fit_transform(df['Career_issue'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# backpapers:0
# career gap:1
# nil:2
# non it background:3
# not it background:4

# %%
df['Looking_for']=le.fit_transform(df['Looking_for'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# it courses:0
# it internship:1
# it work experience:2
# nil:3
# others:4

# %%
df['Technology']=le.fit_transform(df['Technology'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# ai:0
# angular:1
# business analytics:2
# data science:3
# flutter:4
# mern:5
# nil:6
# others:7
# php:8
# python:9
# react:10

# %%
df['Mode']=le.fit_transform(df['Mode'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# hybrid:0
# nil:1
# offline:2
# online:3

# %%
df['Time_Slot']=le.fit_transform(df['Time_Slot'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# afternoon:0
# morning:1
# nil:2
# weekend:3

# %%
df['Attended_by']=le.fit_transform(df['Attended_by'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# anupama:0
# anusree:1
# athulya:2
# baiju:3
# deepak:4
# faisal:5
# legha:6
# lekha:7
# monish:8
# nil:9
# praveena:10
# remin:11
# rifna:12
# shafeeque:13
# shiju:14
# sivaprasad:15

# %%
df['Remarks']=le.fit_transform(df['Remarks'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# call not picking:0
# cancelled:1
# closed lost:2
# digital marketing:3
# enquired for friend:4
# faculty shortage:5
# fake:6
# going for higher studies:7
# having backpapers:8
# high fee:9
# joined:10
# joined other institution:11
# looking for ui/ux:12
# nil:13
# no certificate needed:14
# no contacts:15
# no update:16
# not applicable:17
# not intrested:18
# not joined:19
# not looking it:20
# not responding:21
# number busy:22
# rush shedule:23
# sample enquiry:24
# suspected:25
# waiting for interview result:26
# went abroad:27
# will update:28

# %%
df['Course_duration']=le.fit_transform(df['Course_duration'])
for i,label in enumerate(le.classes_):
    print(f'{label}:{i}')
# Out:
# One month:0
# Six month:1
# three month:2

# %% [markdown]
# # Model Train Test Spliting and Evaluation

# %%
fet=['Find_us','Qualification','Career_issue','Looking_for','Technology','Mode','Time_Slot','Attended_by','No_persons','Year_Of_pass_out','Year_Of_Enq','Course_duration','Remarks']
x=df[fet]
y=df['Status']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
xtrain.head()
# Out:
#      Find_us  Qualification  Career_issue  Looking_for  Technology  Mode  \
# 305        1              0             2            1           9     2
# 22         1              4             2            1           9     2
# 307        1              8             2            1           9     2
# 46         4              4             4            0           4     2
# 470        1              6             2            1           9     2
#
#      Time_Slot  Attended_by  No_persons Year_Of_pass_out  Year_Of_Enq  \
# 305          1            3           1           2015.0         2021
# 22           1           11           2           2024.0         2024
# 307          1            3           1           2019.0         2021
# 46           1            3           2           2025.0         2025
# 470          1            3           1             2025         2022
#
#      Course_duration  Remarks
# 305                2       10
# 22                 1       25
# ...

# %% [markdown]
# ytrain.head()

# %% [markdown]
# # Logistic Regression Model

# %%
lr=LogisticRegression()
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report,confusion_matrix
ypred=lr.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          nil       0.00      0.00      0.00         6
#           no       0.74      0.66      0.70        47
#          yes       0.60      0.76      0.67        42
#
#     accuracy                           0.66        95
#    macro avg       0.45      0.47      0.46        95
# weighted avg       0.63      0.66      0.64        95

# %% [markdown]
# > Model Performing Good avg of 84% accurate

# %% [markdown]
# # Confusion matrix

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Decision Tree Classifier

# %%
dc=DecisionTreeClassifier()
dc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
ypred1=dc.predict(xtest)
print(classification_report(ytest,ypred1))
# Out:
#               precision    recall  f1-score   support
#
#          nil       1.00      0.67      0.80         6
#           no       0.96      1.00      0.98        47
#          yes       1.00      1.00      1.00        42
#
#     accuracy                           0.98        95
#    macro avg       0.99      0.89      0.93        95
# weighted avg       0.98      0.98      0.98        95

# %% [markdown]
# # Confusion matrix

# %%
sns.heatmap(confusion_matrix(ytest,ypred1),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
ypred2=rf.predict(xtest)
print(classification_report(ytest,ypred2))
# Out:
#               precision    recall  f1-score   support
#
#          nil       1.00      0.17      0.29         6
#           no       0.96      0.98      0.97        47
#          yes       0.91      1.00      0.95        42
#
#     accuracy                           0.94        95
#    macro avg       0.96      0.72      0.74        95
# weighted avg       0.94      0.94      0.92        95

# %% [markdown]
# # Confusion matrix

# %%
sns.heatmap(confusion_matrix(ytest,ypred2),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Support Vector Machine Classifier

# %%
svc=SVC()
svc.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
ypred3=svc.predict(xtest)
print(classification_report(ytest,ypred3))
# Out:
#               precision    recall  f1-score   support
#
#          nil       0.00      0.00      0.00         6
#           no       0.00      0.00      0.00        47
#          yes       0.44      1.00      0.61        42
#
#     accuracy                           0.44        95
#    macro avg       0.15      0.33      0.20        95
# weighted avg       0.20      0.44      0.27        95

# %% [markdown]
# # Confusion matrix

# %%
sns.heatmap(confusion_matrix(ytest,ypred3),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# > Every Model Has High Accuracy ,Next building ensemble model wit null values

# %% [markdown]
# # Ensemble with null values

# %%
df['Find_us']=df['Find_us'].replace({1:np.nan})
df['Career_issue']=df['Career_issue'].replace({2:np.nan})

# %%
fet=['Find_us','Qualification','Career_issue','Looking_for','Technology','Mode','Time_Slot','Attended_by','No_persons','Year_Of_pass_out','Year_Of_Enq','Course_duration','Remarks']
x=df[fet]
y=df['Status']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
rf1=RandomForestClassifier(n_estimators=1000,random_state=42)
rf1.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=42)

# %%
ypred0=rf1.predict(xtest)
print(classification_report(ytest,ypred0))
# Out:
#               precision    recall  f1-score   support
#
#          nil       1.00      0.33      0.50         6
#           no       0.96      0.98      0.97        47
#          yes       0.93      1.00      0.97        42
#
#     accuracy                           0.95        95
#    macro avg       0.96      0.77      0.81        95
# weighted avg       0.95      0.95      0.94        95

# %%
sns.heatmap(confusion_matrix(ytest,ypred0),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# > Most accurate model

# %%
import joblib

# %%
'''joblib.dump(lr,"ED_logistic_model.pkl")
joblib.dump(dc,"ED_decision_t_model.pkl")
joblib.dump(rf,"ED_random_f_model.pkl")
joblib.dump(svc,"ED_svc_model.pkl")
joblib.dump(rf1,"ED_rf_withnull_model.pkl")'''
# Out:
# 'joblib.dump(lr,"ED_logistic_model.pkl")\njoblib.dump(dc,"ED_decision_t_model.pkl")\njoblib.dump(rf,"ED_random_f_model.pkl")\njoblib.dump(svc,"ED_svc_model.pkl")\njoblib.dump(rf1,"ED_rf_withnull_model.pkl")'
